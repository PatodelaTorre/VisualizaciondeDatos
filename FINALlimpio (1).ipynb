# %% [markdown]
# # Presentacion final
# ### Patricio de la Torre A00826990

# %%
import seaborn as sns # For plotting
import pandas as pd
import matplotlib.pyplot as plt # For showing plots
import statsmodels.api as sm
import numpy as np
from sklearn import linear_model

# Load in the data set
df = pd.read_csv('fifa21_male2.csv')
df
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3173: DtypeWarning: Columns (78) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            ID             Name  Age  OVA            Nationality  \
# 0           2      G. Pasquale   33   69                  Italy
# 1          16      Luis García   37   71                  Spain
# 2          27          J. Cole   33   71                England
# 3          36         D. Yorke   36   68  Trinidad &amp; Tobago
# 4          41          Iniesta   36   81                  Spain
# ...       ...              ...  ...  ...                    ...
# 17120  259088       A. Medioub   22   64                 France
# 17121  259090       W. Rickard   18   56                  Wales
# 17122  259091       C. Barrett   18   56                England
# 17123  259101   J. Gazibegović   20   62     Bosnia Herzegovina
# 17124  259105  Pablo Rodríguez   18   59                  Spain
#
#                 Club  BOV   BP      Position  \
# 0            Udinese   71  LWB            LM
# 1          KAS Eupen   70   CM    CM CAM CDM
# 2      Coventry City   71  CAM  CAM RM RW LM
# 3         Sunderland   70   ST           NaN
# 4        Vissel Kobe   82  CAM        CM CAM
# ...              ...  ...  ...           ...
# 17120     CD Tondela   66   CB            CB
# 17121        Burnley   58  CAM        CAM CM
# 17122        Burnley   56   RB            RB
# 17123  SK Sturm Graz   62   RB         RB LB
# 17124          Lecce   61   ST            ST
#
#                                             Player Photo  ...    CDM    RDM  \
# 0      https://cdn.sofifa.com/players/000/002/16_120.png  ...  70+-1  70+-1
# 1      https://cdn.sofifa.com/players/000/016/19_120.png  ...   66+1   66+1
# 2      https://cdn.sofifa.com/players/000/027/16_120.png  ...   54+0   54+0
# 3      https://cdn.sofifa.com/players/000/036/09_120.png  ...   65+0   65+0
# 4      https://cdn.sofifa.com/players/000/041/20_120.png  ...   73+3   73+3
# ...                                                  ...  ...    ...    ...
# 17120  https://cdn.sofifa.com/players/259/088/20_120.png  ...   55+2   55+2
# 17121  https://cdn.sofifa.com/players/259/090/20_120.png  ...   52+2   52+2
# 17122  https://cdn.sofifa.com/players/259/091/20_120.png  ...   50+2   50+2
# 17123  https://cdn.sofifa.com/players/259/101/20_120.png  ...   58+2   58+2
# 17124  https://cdn.sofifa.com/players/259/105/20_120.png  ...   32+2   32+2
#
#          RWB     LB   LCB    CB   RCB     RB    GK Gender
# 0      71+-2  70+-1  69+0  69+0  69+0  70+-1  17+0   Male
# 1       62+1   60+1  60+1  60+1  60+1   60+1  17+1   Male
# 2       52+0   47+0  46+0  46+0  46+0   47+0  15+0   Male
# 3       56+0   57+0  51+0  51+0  51+0   57+0  22+0   Male
# 4       70+3   67+3  64+3  64+3  64+3   67+3  17+3   Male
# ...      ...    ...   ...   ...   ...    ...   ...    ...
# 17120   54+2   57+2  64+2  64+2  64+2   57+2  12+2   Male
# 17121   53+2   52+2  49+2  49+2  49+2   52+2  17+2   Male
# 17122   54+2   54+2  54+2  54+2  54+2   54+2  14+2   Male
# 17123   60+2   60+2  58+2  58+2  58+2   60+2  16+2   Male
# 17124   36+2   34+2  30+2  30+2  30+2   34+2  14+2   Male
#
# [17125 rows x 107 columns]

# %% [markdown]
# # Introduccion
# ### Mi base de datos tiene la infromacion de los jugadores que aparecen en el FIFA 2021. Esta base de datos tiene 107 variabes y 17,125 datos.

# %% [markdown]
# ## Mis variables de interes, con las cuales voy a trabajar son las siguientes:
# #### 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'Position', ya que las demas no aportan un valor reral a esta investigacion.

# %%
df.drop(['ID', 'POT', 'Team & Contract', 'foot','Growth', 'Joined', 'Loan Date End', 'Release Clause','Contract', 'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy','Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve','FK Accuracy', 'Long Passing', 'Ball Control', 'Movement','Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance','Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots','Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision','Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle','Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling','GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats','Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS','DRI', 'DEF', 'PHY', 'Hits', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF','RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB','LDM','Player Photo','CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'Gender', 'BOV', 'BP','Club Logo', 'Flag Photo','Height','Weight', 'Value', 'Wage'],
       inplace = True,
        axis = 1
       )
df
# Out:
#                   Name  Age  OVA            Nationality           Club  \
# 0          G. Pasquale   33   69                  Italy        Udinese
# 1          Luis García   37   71                  Spain      KAS Eupen
# 2              J. Cole   33   71                England  Coventry City
# 3             D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland
# 4              Iniesta   36   81                  Spain    Vissel Kobe
# ...                ...  ...  ...                    ...            ...
# 17120       A. Medioub   22   64                 France     CD Tondela
# 17121       W. Rickard   18   56                  Wales        Burnley
# 17122       C. Barrett   18   56                England        Burnley
# 17123   J. Gazibegović   20   62     Bosnia Herzegovina  SK Sturm Graz
# 17124  Pablo Rodríguez   18   59                  Spain          Lecce
#
#            Position
# 0                LM
# 1        CM CAM CDM
# 2      CAM RM RW LM
# 3               NaN
# 4            CM CAM
# ...             ...
# 17120            CB
# 17121        CAM CM
# 17122            RB
# 17123         RB LB
# 17124            ST
#
# [17125 rows x 6 columns]

# %% [markdown]
# ## En este caso terminamos con 6 variables, las cuales seran utilizadas para las preguntas posteriores.
# ### Hay 2 variables numericas enteras:
#
# * Age es la edad y es una variable nominal
#
# * OVA es la calificacion promedio del jugador esta es un variable cuantitativa
#
#
# ### Por el otro lado hay 4 variables categoricas
# * Name es el nombre de cada jugador
#
# * Nationality describe la nacionalidad de cada jugador
#
# * Club es el club en el que juegan actualmente
#
# * Position es la posicion en la que se desempena el jugador

# %% [markdown]
# ## Algunos hallazgos interesante que descubri al analizar esos datos son ls siguiente:
# * La edad mediana de los jugadores en el FIFA 2021 es de 25 anios
#
# * La mayoria de los jugaodres tiene un promedio de entre 60 y 70 puntos de calificacion
#
# * Existe una correlacion positiva fuerte entre la edad de los jugadores y su calificacion promedio
#
# * EL pais con menor calificacion promedio es Hong Kong
#
# * El pais con mas jugadores en el juego es Inglaterra

# %% [markdown]
# # _________________________________________________________________________________

# %% [markdown]
# ## PREGUNTA 1: Cual es el rango de edad de los jugadores en el FIFA 2021

# %%
sns.boxplot(x = df["Age"], 
            whis=(0, 100),
           ).set_title("Box plot of Age")

plt.show()

# %% [markdown]
# ## Conclusion:
# La edad mediana de los jugadores en FIFA 2021 es de 25 anios

# %% [markdown]
# # _________________________________________________________________________________

# %% [markdown]
# ## Pregunta 2: Cuales son las 10 nacionalidad con mas jugadores en el FIFA 2021

# %%
counts = df['Nationality'].value_counts()
type(counts)
counts = counts.to_frame() #para hacerlo una tabla
#print(type(counts))
#print(counts)
counts['%'] = counts.loc[:,'Nationality']/counts.loc[:,'Nationality'].sum(axis = 0)*100
counts10 = counts.head(10)

# %%
counts10['Nationality'].plot(kind = 'pie',
                  figsize = (15,6),   
                   autopct = '%2.f%%',
                   shadow = False
                  )
plt.legend(labels = counts10.Nationality,
           title = '# de jugadores',
           title_fontsize = 12,
          bbox_to_anchor = (1.7, 1)
          )
plt.title('Piechart of Nationality count', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Piechart of Nationality count')

# %% [markdown]
# ## Conclusion:
# Estos son las paises con mas jugadores, pero Inglaterra es el que mas jugadores tiene en el FIFA 2021, siendo el 20% de los jugadores totales de esta nacionalidad

# %% [markdown]
# # _________________________________________________________________________________

# %% [markdown]
# ## PREGUNTA 3: Como esta la distribucion de calificacion promedio de los jugadores de FIFA 2021

# %%
sns.histplot(df["OVA"], 
             kde = False).set_title("Histogram of OVA")

plt.show()

# %% [markdown]
# ## Conclusion:
# La mayoria de los jugadores tienen un promedio de entre 60 y 70 puntos totales

# %% [markdown]
# # _________________________________________________________________________________

# %% [markdown]
# ## PREGUNTA 4: Cuales son las nacionalidades con menor promedio de OVA de sus jugadores en el FIFA 2021

# %%
my_pivot3 = pd.pivot_table(df,
                          index = ['Nationality'],
                          values = ['OVA'],
                          #aggfunc = ['std','sum','mean','median']
                          aggfunc = 'mean',
                        
                          margins = True
                         )
my_pivot3

mysort = my_pivot3.sort_values('OVA')
mysort15 = mysort.head(10)

sns.set(rc={'figure.figsize' : (8,6)})
mysort15.plot.barh()
plt.title('Bar graph Nationalities with less OVA', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Bar graph Nationalities with less OVA')

# %% [markdown]
# ## Conclusion:
# EL pais con el menor promedio de calificaciones de jugadores en el FIFA 2021 es Hong Kong

# %% [markdown]
# # _________________________________________________________________________________

# %% [markdown]
# ## PREGUNTA 5: Existe una correlacion entre la edad y la calificacion asignada a un jugador

# %%
sns.lmplot(x='Age', 
           y='OVA', 
           data= df,
           size=8
          )
plt.title('Scatterplot Age vs OVA', fontsize = 15)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Conclusion:
# Existe una correlacion fuerte y positiva entre la Edad y la calificacion promedio, lo cual significa que entre mayor sea la edad, en la mayoria de los casos, se espera que la calificacion sea mayor, estando las calificaciones mas altas antes de los 38 anios aproximadamente, despues empieza a bajar

# %% [markdown]
# # _________________________________________________________________________________

# %% [markdown]
# ## Pregunta 6: Cual es la calificacion promedio por edad de los jugadores mexicanos en el FIFA 2021

# %%
condition = df['Nationality'] ==( 'Mexico')

my_pivot = pd.pivot_table(df[condition],
                        index = ['Age'],values = ['OVA'],aggfunc = 'mean',
                        margins = True,

                                    
                          
                         )
sns.set(rc={'figure.figsize' : (8,8)})

my_pivot.plot()
plt.title('Mean OVA per Age in Mexican players', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Mean OVA per Age in Mexican players')

# %% [markdown]
# ## Conclusion:
# Se puede ver como en los mexicanos, el mayor nivel de calificacion promedio se observa entre los 33 y 36 anios

# %% [markdown]
# # _________________________________________________________________________________

# %% [markdown]
# ## Pregunta 7: Cual es el impacto de AGE en OVA (calificacion promedio)?

# %%
modelA = sm.OLS.from_formula('OVA ~ Age', data=df)
resultA = modelA.fit()
resultA.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    OVA   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     6250.
# Date:                Thu, 02 Dec 2021   Prob (F-statistic):               0.00
# Time:                        23:02:03   Log-Likelihood:                -54623.
# No. Observations:               17125   AIC:                         1.093e+05
# Df Residuals:                   17123   BIC:                         1.093e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     48.8155      0.234    208.674      0.000      48.357      49.274
# Age            0.7181      0.009     79.055      0.000       0.700       0.736
# ==============================================================================
# Omnibus:                      278.506   Durbin-Watson:                   1.636
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              348.398
# Skew:                           0.238   Prob(JB):                     2.22e-76
# Kurtosis:                       3.511   Cond. No.                         134.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Obsevaciones
# * Variable dependiente: OVA
# * Variable independiente: Age
# * R-squared: 0.267; por lo tanto, este modelo no es eficiente.
# * Df Model:	1
# * intercept ... > 48.8155	, es estadisticamente significativo
#
# `OVA = 48.8155	 + 0.7181*Age`

# %%
print('El OVA de un jugador con 33 anios de edad seria: \t', 48.8155     + 0.7181*33)
df.iloc[:3,:]
# Out:
# El OVA de un jugador con 33 anios de edad seria: 	 72.5128
#           Name  Age  OVA Nationality           Club      Position
# 0  G. Pasquale   33   69       Italy        Udinese            LM
# 1  Luis García   37   71       Spain      KAS Eupen    CM CAM CDM
# 2      J. Cole   33   71     England  Coventry City  CAM RM RW LM

# %%
plt.figure(figsize = (15,10))
sns.set(font_scale = 1.7)

reg_plot = sns.regplot( x = 'Age',
            y = 'OVA',
            data = df,
           marker = 'x',
           color = 'red',
                      scatter_kws = {'s':200}
                      )
reg_plot.set_title('Regression plot of Age vs OVA')
reg_plot.text(35, 40, 'OVA = 48.8155     + 0.7181*Age',
              color = 'blue',
              weight = 'semibold',
              size = 'medium'
             )
# Out:
# Text(35, 40, 'OVA = 48.8155     + 0.7181*Age')

# %%
RESIA = resultA.resid
RESIA
# Out:
# 0       -3.514156
# 1       -4.386725
# 2       -1.514156
# 3       -6.668583
# 4        6.331417
#            ...
# 17120   -0.614589
# 17121   -5.742019
# 17122   -5.742019
# 17123   -1.178304
# 17124   -2.742019
# Length: 17125, dtype: float64

# %%
resi_plot = sns.scatterplot(x = resultA.fittedvalues,
                            y = RESIA)

# %% [markdown]
# ## Conclusion:
# Despues de analizar los resultados del analisis de regresion, junto con su grafico y el de los residuos, se conclue que el modelo es adecuado para predecir, lo cual significa que existe una clara relacion entre la edad del un jugador y su calificacion promedio

# %% [markdown]
# # _________________________________________________________________________________
